# %% [markdown]
# # Aula 04

# %% [markdown]
# ### 1a Atividade

# %%
meu_livro = "Python para Iniciantes"
print(meu_livro)
# Out:
# Python para Iniciantes

# %%
meu_livro = "Algoritmos Divertidos"
print(meu_livro)
# Out:
# Algoritmos Divertidos

# %%
PI = 3.14159
GRAVIDADE = 9.8

# %%
type(GRAVIDADE)
# Out:
# float

# %%
GRAVIDADE = 9, 8
print(GRAVIDADE)
print(GRAVIDADE[1])
# Out:
# (9, 8)
# 8

# %% [markdown]
# # Desafio 02

# %%
nome = input("Digite o seu nome : ")
ano_nascimento = input("Digite o ano do seu nascimento : ")
print(nome)
print(f"Seu nome é {nome}")
ano_nascimento_int = int(ano_nascimento)
idade = (2026 - ano_nascimento_int)
print(f"{nome}, sua idade aproximada é {idade}")
# Out:
# Uelison
# Seu nome é Uelison
# Uelison, sua idade aproximada é 28

# %% [markdown]
# # Tipos de Dados

# %% [markdown]
# ### Número(int, float, complex)

# %%
inteiro = 10
ponto_flutuante = 3.14
numero_complexo = 2 + 3j

# %%
print(type(inteiro))
print(type(ponto_flutuante))
print(type(numero_complexo))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# # Testando as strings

# %%
nome = "Luis Rodrigo"
cep = "25645-045"
logradouro = """Rua São Sebastiao, 222
Bairro: São Sebastião
Cidade: Petrópolis
Estado: RJ"""

# %%
print(nome)
print(cep)
print(logradouro)
# Out:
# Luis Rodrigo
# 25645-045
# Rua São Sebastiao, 222
# Bairro: São Sebastião
# Cidade: Petrópolis
# Estado: RJ

# %% [markdown]
# # Variáveis Booleanas

# %%
numero1 = 5
numero2 = 7
resultado = numero1 > numero2
resultado2 = numero1 < numero2
print(resultado)
print(resultado2)
# Out:
# False
# True

# %% [markdown]
# # Listas - Tuplas e Ranges

# %%
tupla=(1,2)
type(tupla)
# Out:
# tuple

# %%
lista=[1,2]
type(lista)
# Out:
# list

# %%
print(tupla[1])
# Out:
# 2

# %%
print(lista)
# Out:
# [1, 2]

# %%
tupla[1] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 tupla[1] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %%
lista[1] = 3

# %%
print(lista)
# Out:
# [1, 3]

# %%
lista.append(4)
lista.append(5)

# %%
print(lista)
# Out:
# [1, 3, 4, 5]

# %%
lista = list(range(1,10,2))
print(lista)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# # Estrutura Condicional - Desvio Condicional

# %%
nome = input("Digite o seu nome : ")
ano_nasc = int(input(f"{nome}, digite o ano do seu nascimento :"))

# %%
idade=2026-ano_nasc
idade=12

# %%
if idade >= 18 :
    print(f"{nome}, você é MAIOR de idade!")
else :
    print(f"{nome}, você é MENOR de idade!")
# Out:
# Uelison, você é MENOR de idade!

# %%
if idade >= 18 :
    print(f"{nome}, você é MAIOR de idade!")
elif idade >= 16:
    print(f"{nome}, você é um Adolescente")
else :
    print(f"{nome}, você é MENOR de idade!")
# Out:
# Uelison, você é MENOR de idade!
