# %% [markdown]
# # Aula 6

# %% [markdown]
# ## Estruturas de Repetição

# %%
frutas = ["Maçã", "Limão", "Banana"]
for fruta in frutas:
    print(fruta)
# Out:
# Maçã
# Limão
# Banana

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## While

# %%
contador = 0
while contador < 5:
    print(contador)
    contador += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = 0
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4
