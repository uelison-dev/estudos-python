# %% [markdown]
# # Aula 02

# %%
print("Olá, Mundo!")
# Out:
# Olá, Mundo!

# %%
numero_inteiro=15
numero_real=15,15
texto="Papagaio"

# %%
type(numero_inteiro)
type(numero_real)
type(texto)
# Out:
# str

# %%
print(type(numero_inteiro))
print(type(numero_real))
print(type(texto))
# Out:
# <class 'int'>
# <class 'tuple'>
# <class 'str'>

# %%
print(numero_inteiro)
print(numero_real)
print(texto)
# Out:
# 15
# (15, 15)
# Papagaio

# %%
numero_inteiro+numero_real
numero_inteiro+texto
texto*numero_inteiro
texto2=texto+" "
texto2*numero_inteiro
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 numero_inteiro+numero_real
#       2 numero_inteiro+texto
#       3 texto*numero_inteiro
#       4 texto2=texto+" "
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
idade = input("Digite sua idade : ")
type(idade)
help(input)
idade_numero = int(idade)
type(idade_numero)
idade_numero_2 = int(input("Qual a sua idade : "))
type(idade_numero_2)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.
# int

# %%
ano_atual = 2026
idade_numero_2 = int(input("Qual a sua idade : "))
ano_nascimento = ano_atual - idade_numero_2
print(ano_nascimento)
# Out:
# 1998

# %%
meu_livro = "Python para Iniciantes"
print(meu_livro)

meu_livro = "Algoritmos Divertidos"
print(meu_livro)

PI = 3.14159
GRAVIDADE = 9.8
# Out:
# Python para Iniciantes
# Algoritmos Divertidos

# %% [markdown]
# # Desafio 02

# %% [markdown]
# ### Exercício 1

# %%
idade = 28
print(idade)
nome = "Uelison"
print(f"Seja Bem-vindo ao Python3, {nome}!")
# Out:
# 28
# Seja Bem-vindo ao Python3, Uelison!

# %% [markdown]
# ### Exercício 2

# %%
var_a = 10
var_b = 5
resultado = 0

resultado = var_a + var_b
print(resultado)
resultado = var_a - var_b
print(resultado)
resultado = var_a * var_b
print(resultado)
resultado = var_a / var_b
print(resultado)
# Out:
# 15
# 5
# 50
# 2.0

# %% [markdown]
# ### Exercício 3

# %%
frase = "Uelison, 28 anos"
len(frase)
# Out:
# 16

# %% [markdown]
# ### Exercício 4

# %%
nome_completo = "Uelison Ferreira"
print(nome_completo.upper())
print(nome_completo.lower())
# Out:
# UELISON FERREIRA
# uelison ferreira

# %% [markdown]
# ### Exercício 5

# %%
nome1 = input("Qual o seu nome : ")
idade1 = input("Qual a sua idade : ")
print(f"{nome}, você tem {idade1} anos !")
# Out:
# Uelison, você tem 28 anos !

# %% [markdown]
# ### Exercício 6

# %%
n1 = int(input("Digite um número inteiro : "))
n2 = int(input("Digite outro número inteiro : "))
resultado = (n1 + n2)
print(f"{n1} + {n2} é igual a {resultado}!")
# Out:
# 7 + 8 é igual a 15!

# %% [markdown]
# ### Exercício 7

# %%
x = 2
y = 4
print(f" O valor das variáveis são X: {x}, Y: {y}")
x = int(input("Digite o novo valor de x : "))
y = int(input("Digite o novo valor de y : "))
print(f"X : {x}, Y: {y}")
# Out:
#  O valor das variáveis são X: 2, Y: 4
# X : 79, Y: 856

# %% [markdown]
# ### Exercício 8

# %%
largura = 0,0
altura = 0,0

largura = float(input("Digite a largura do retangulo em (m²) : "))
altura = float(input("Digite a altura do retangulo em (m²) : "))

area = largura * altura
print(f"A área do retangulo é de {area}(m²).")
# Out:
# A área do retangulo calculada é de 27.0(m²).

# %% [markdown]
# ### Exercício 9

# %%
print("Formúla:  P = 4 x 1(lado do quadrado que possuo o número.)")
lado = 0
lado = float(input("Digite o número do lado de um quadrado : "))
P = 4 * lado
print(f"O perimetro do quadrado é: {P}")
# Out:
# Formúla:  P = 4 x 1(lado do quadrado que possuo o número.)
# O perimetro do quadrado é: 28.0

# %% [markdown]
# ### Exercício 10

# %%
salario = 1945
novo_salario = salario * 1.10
print(f"Novo salário: R${novo_salario}")
# Out:
# Novo salário: R$2139.5
